# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier

iris_dataset = load_iris()

#train test split
X_train,X_test,y_train,y_test = train_test_split(irise_dataset["data"],irise_dataset["target"],random_state =1)

#create scatter plot
iris_dataframe = pd.DataFrame(X_train, columns=iris_dataset.feature_names)
pd.plotting.scatter_matrix(iris_dataframe, c=y_train, figsize=(15,15),marker='o',alpha=.8 )

#KNN 
K=8
knn = KNeighborsClassifier(n_neighbors = K)
knn.fit(X_train,y_train)

prediction = knn.predict(X_test)
correct = 0
for i in range(len(prediction)):
    if prediction[i] == y_test[i]:
        correct+=1
print(f"Percentage of correct prediction with K={K}: {correct/len(prediction)*100}%")
# Out:
# Percentage of correct prediction with K=8: 100.0%
